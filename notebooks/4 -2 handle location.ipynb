# %%
import pandas as pd

# %%
# Load the datasets
original_sales_data = pd.read_csv('../data/snp_dld_2024_transactions.csv', low_memory=False)
original_rentals_data = pd.read_csv('../data/snp_dld_2024_rents.csv', low_memory=False)
# Load the processed dfs
sales_data = pd.read_csv('../data/sales_data_no_missing.csv', low_memory=False)
rentals_data = pd.read_csv('../data/rentals_data_no_missing.csv', low_memory=False)

# %%
original_sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162806 entries, 0 to 162805
# Data columns (total 46 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   transaction_number      162806 non-null  object
#  1   transaction_datetime    162806 non-null  object
#  2   transaction_type_en     162806 non-null  object
#  3   transaction_type_id     162806 non-null  int64
#  4   transaction_subtype_en  162806 non-null  object
#  5   transaction_subtype_id  162806 non-null  int64
#  6   registration_type_en    162806 non-null  object
#  7   is_freehold_text        162806 non-null  object
#  8   property_usage_en       162806 non-null  object
#  9   property_usage_id       162806 non-null  int64
#  10  amount                  162806 non-null  float64
#  11  total_buyer             162806 non-null  int64
#  12  total_seller            162806 non-null  int64
#  13  transaction_size_sqm    162146 non-null  float64
#  14  property_size_sqm       162806 non-null  float64
#  15  parcel_id               60451 non-null   float64
#  16  property_id             162806 non-null  int64
#  17  is_offplan              162806 non-null  object
#  18  is_freehold             162122 non-null  object
#  19  property_type_en        162806 non-null  object
#  20  property_type_ar        162806 non-null  object
#  21  property_type_id        162806 non-null  int64
#  22  property_subtype_en     161414 non-null  object
#  23  property_subtype_ar     161414 non-null  object
#  24  property_subtype_id     162806 non-null  int64
#  25  building_age            162806 non-null  int64
#  26  rooms_en                139549 non-null  object
#  27  rooms_ar                141444 non-null  object
#  28  parking                 122343 non-null  object
#  29  project_name_en         138046 non-null  object
#  30  project_name_ar         138046 non-null  object
#  31  area_en                 162806 non-null  object
#  32  area_ar                 162806 non-null  object
#  33  area_id                 162806 non-null  int64
#  34  nearest_landmark_en     115394 non-null  object
#  35  nearest_landmark_ar     115394 non-null  object
#  36  nearest_metro_en        96824 non-null   object
#  37  nearest_metro_ar        96824 non-null   object
#  38  nearest_mall_en         95964 non-null   object
#  39  nearest_mall_ar         95964 non-null   object
#  40  master_project_en       346 non-null     object
#  41  master_project_ar       346 non-null     object
#  42  req_from                162806 non-null  object
#  43  req_to                  162806 non-null  object
#  44  entry_id                162806 non-null  int64
#  45  meta_ts                 162806 non-null  object
# dtypes: float64(4), int64(11), object(31)
# memory usage: 57.1+ MB

# %%
location_columns_sales = [
    "project_name_en",
    "project_name_ar",
    "area_en",
    "area_ar",
    "area_id",
    "nearest_landmark_en",
    "nearest_landmark_ar",
    "nearest_metro_en",
    "nearest_metro_ar",
    "nearest_mall_en",
    "nearest_mall_ar",
    "master_project_en",
    "master_project_ar"
]

# %%
location_data_sales = original_sales_data[location_columns_sales]

# %%
aarea_group = location_data_sales.groupby('area_en').agg({
    'project_name_en': 'count',        # Non-null project names
    'nearest_landmark_en': 'count',   # Non-null nearest landmarks
    "nearest_metro_en": 'count',      # Non-null nearest metro entries
    "nearest_mall_en": 'count',       # Non-null nearest mall entries
}).reset_index()

# Rename columns for clarity
area_group.rename(columns={
    'project_name_en': 'project_count',
    'nearest_landmark_en': 'landmark_count',
    'nearest_metro_en': 'metro_count',
    'nearest_mall_en': 'mall_count'
}, inplace=True)

# %%
area_group.tail()
# Out:
#             area_en  project_count  landmark_count  metro_count  mall_count
# 268  Wadi Al Safa 7           1311             304            0           0
# 269    Warsan First             68              48           72          72
# 270   Warsan Fourth              0               0            0           0
# 271   Zaabeel First           1795            1729         1729        1729
# 272  Zaabeel Second            398             398          398         398

# %%
from geopy.geocoders import Nominatim

# Initialize the geolocator
geolocator = Nominatim(user_agent="geoapi")

# Arabic address or place name
location = geolocator.geocode("دبي")

# %%
location
# Out:
# Location(دبي, الإمارات العربية المتحدة, (25.2653471, 55.2924914, 0.0))

# %%
df = location_data_sales

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import time
import logging
import os
from tqdm import tqdm  # For progress bar

# Initialize logging
logging.basicConfig(filename="geocoding_errors.log", level=logging.ERROR)

# Initialize the geolocator with a higher timeout
geolocator = Nominatim(user_agent="geoapi", timeout=10)

# Define Dubai's approximate coordinates
dubai_coordinates = (25.276987, 55.296249)

# Cache to avoid redundant requests
coordinate_cache = {}

# Function to check if coordinates are within Dubai
def is_within_dubai(lat, lon, dubai_center=dubai_coordinates, max_distance_km=50):
    """Check if a location is within a reasonable distance of Dubai."""
    if lat is None or lon is None:
        return False
    distance = geodesic((lat, lon), dubai_center).km
    return distance <= max_distance_km

# Function to get coordinates with caching, retries, and rate limiting
def get_coordinates(location):
    """Fetch coordinates for a given location."""
    if location in coordinate_cache:
        return coordinate_cache[location]  # Return from cache if available

    try:
        time.sleep(1)  # Respect rate limit (1 request per second)
        loc = geolocator.geocode(location)
        if loc:
            lat, lon = loc.latitude, loc.longitude
            coordinate_cache[location] = (lat, lon)  # Save to cache
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching coordinates for {location}: {e}")
    return None, None

# Function to fetch coordinates for an area with fallback logic
def fetch_coordinates_for_area(row):
    """Fetch coordinates for an area using multiple fallback fields."""
    fields = [
        'area_en', 'area_ar', 'project_name_en', 'project_name_ar',
        'nearest_landmark_en', 'nearest_landmark_ar', 
        'nearest_metro_en', 'nearest_metro_ar', 
        'nearest_mall_en', 'nearest_mall_ar', 
        'master_project_en', 'master_project_ar'
    ]
    
    for field in fields:
        location = row.get(field)
        if pd.notnull(location):  # Only process non-null locations
            lat, lon = get_coordinates(location)
            if is_within_dubai(lat, lon):  # Validate if coordinates are in Dubai
                return lat, lon

    # Return None if no valid coordinates found
    return None, None

# Check if a saved CSV exists for coordinates
coordinates_csv = "area_coordinates.csv"
if os.path.exists(coordinates_csv):
    # Load cached coordinates from CSV
    print(f"Loading cached coordinates from {coordinates_csv}...")
    unique_areas = pd.read_csv(coordinates_csv)
    coordinate_cache = {
        row['area_en']: (row['latitude'], row['longitude'])
        for _, row in unique_areas.iterrows()
    }
else:
    # Preprocess to get unique areas
    unique_areas = df.groupby('area_en').first().reset_index()

    # Apply geocoding to unique areas with a progress bar
    tqdm.pandas(desc="Geocoding Areas")  # Add description to progress bar
    unique_areas[['latitude', 'longitude']] = unique_areas.progress_apply(
        fetch_coordinates_for_area, axis=1, result_type='expand'
    )

    # Save unique area coordinates to CSV for future runs
    unique_areas.to_csv(coordinates_csv, index=False)
    print(f"Saved coordinates to {coordinates_csv}.")

# Merge the coordinates back to the original dataset
df = pd.merge(df, unique_areas[['area_en', 'latitude', 'longitude']], on='area_en', how='left')

# Save the full dataset with coordinates to a CSV
final_csv = "dataset_with_coordinates.csv"
df.to_csv(final_csv, index=False)
print(f"Saved the dataset with coordinates to {final_csv}.")
# Out:
# Geocoding Areas: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 273/273 [1:01:41<00:00, 13.56s/it]
# Saved coordinates to area_coordinates.csv.
# Saved the dataset with coordinates to dataset_with_coordinates.csv.

# %%
coordinate_cache
# Out:
# {}

# %%
# Check if each area_en has coordinates
unique_areas['has_coordinates'] = unique_areas[['latitude', 'longitude']].notnull().all(axis=1)

# Print areas without coordinates
missing_coordinates = unique_areas[~unique_areas['has_coordinates']]
if not missing_coordinates.empty:
    print(f"Areas without coordinates:\n{missing_coordinates[['area_en']]}")
else:
    print("All areas have coordinates!")
# Out:
# Areas without coordinates:
#               area_en
# 0           AL Athbah
# 1           AL BARARI
# 2           AL FURJAN
# 3    AL KHAIL HEIGHTS
# 4             AL WAHA
# ..                ...
# 268    Wadi Al Safa 7
# 269      Warsan First
# 270     Warsan Fourth
# 271     Zaabeel First
# 272    Zaabeel Second
#
# [273 rows x 1 columns]

# %%
missing_coordinates[['area_en']].isnull()
# Out:
#      area_en
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 268    False
# 269    False
# 270    False
# 271    False
# 272    False
#
# [273 rows x 1 columns]

# %%
unique_area = location_data_sales['area_en'].unique()

# %%
unique_areas
# Out:
#               area_en    project_name_en    project_name_ar        area_ar  \
# 0           AL Athbah               None               None         العذبة
# 1           AL BARARI     SEVENTH HEAVEN           سفنث هفن        البراري
# 2           AL FURJAN      EQUITI ARCADE      ايكويتي اركيد        الفرجان
# 3    AL KHAIL HEIGHTS   AL KHAIL HEIGHTS        الخيل هايتس    الخيل هايتس
# 4             AL WAHA      SIENNA  LAKES          سينا ليكس         الواحة
# ..                ...                ...                ...            ...
# 268    Wadi Al Safa 7            Rukan 3            روكان 3   وادي الصفا 7
# 269      Warsan First    Olivz Residence      اوليفز رزيدنس   ورسان الاولى
# 270     Warsan Fourth               None               None  ورسان الرابعة
# 271     Zaabeel First       One Za'abeel          ون زعبيل    زعبيل الاولى
# 272    Zaabeel Second  Downtown Views II  II داون تاون فيوز  زعبيل الثانيه
#
#      area_id          nearest_landmark_en       nearest_landmark_ar  \
# 0          0                         None                      None
# 1          0         IMG World Adventures  آي إم جي وورلد أدفينتشرز
# 2          0               Expo 2020 Site           موقع إكسبو 2020
# 3          0               Downtown Dubai             وسط مدينة دبي
# 4          0         Dubai Cycling Course         دورة دبي للدراجات
# ..       ...                          ...                       ...
# 268        0        Hamdan Sports Complex        مجمع حمدان الرياضي
# 269        0  Dubai International Airport           مطار دبي الدولي
# 270        0                         None                      None
# 271        0                 Burj Khalifa                 برج خليفة
# 272        0                 Burj Khalifa                 برج خليفة
#
#               nearest_metro_en     nearest_metro_ar     nearest_mall_en  \
# 0                         None                 None                None
# 1      Noor Bank Metro Station    محطة مترو نور بنك                None
# 2    Ibn Battuta Metro Station  محطة مترو ابن بطوطة  Ibn-e-Battuta Mall
# 3      Noor Bank Metro Station    محطة مترو نور بنك          Dubai Mall
# 4                         None                 None                None
# ..                         ...                  ...                 ...
# 268                       None                 None                None
# 269    Rashidiya Metro Station   محطة مترو الراشدية  City Centre Mirdif
# 270                       None                 None                None
# 271  Al Jafiliya Metro Station   محطة مترو الجافلية          Dubai Mall
# 272           Financial Centre        المركز المالي          Dubai Mall
#
#     nearest_mall_ar                      master_project_en  \
# 0              None                                   None
# 1              None                                   None
# 2     ابن بطوطة مول  Jebel Ali Village Townhouses- Phase 1
# 3           مول دبي                                   None
# 4              None                                   None
# ..              ...                                    ...
# 268            None                                   None
# 269  سيتي سنتر مردف                                   None
# 270            None                                   None
# 271         مول دبي                                   None
# 272         مول دبي                                   None
#
#                       master_project_ar latitude longitude  has_coordinates
# 0                                  None     None      None            False
# 1                                  None     None      None            False
# 2    قرية جبل علي تاون هاوسز- المرحلة 1     None      None            False
# 3                                  None     None      None            False
# 4                                  None     None      None            False
# ..                                  ...      ...       ...              ...
# 268                                None     None      None            False
# 269                                None     None      None            False
# 270                                None     None      None            False
# 271                                None     None      None            False
# 272                                None     None      None            False
#
# [273 rows x 16 columns]

# %%
import pandas as pd
import os
from geopy.geocoders import Nominatim
from concurrent.futures import ThreadPoolExecutor
import time

# Initialize geopy geolocator
geolocator = Nominatim(user_agent="geoapi")
geocoded_locations = {}  # Cache for geocoded locations

# Define Dubai's geographic coordinate range (expanded for tolerance)
DUBAI_LAT_RANGE = (24.0, 26.5)
DUBAI_LON_RANGE = (54.0, 56.0)

def is_within_dubai(lat, lon):
    """Check if coordinates are within Dubai."""
    return DUBAI_LAT_RANGE[0] <= lat <= DUBAI_LAT_RANGE[1] and DUBAI_LON_RANGE[0] <= lon <= DUBAI_LON_RANGE[1]

def fetch_lat_long(location_name):
    """Fetch latitude and longitude for a location."""
    if location_name in geocoded_locations:
        return geocoded_locations[location_name]
    try:
        location = geolocator.geocode(location_name)
        if location:
            geocoded_locations[location_name] = (location.latitude, location.longitude)
            return location.latitude, location.longitude
    except Exception as e:
        pass
    geocoded_locations[location_name] = (None, None)
    return None, None

def process_area(area_name):
    """Fetch coordinates for an area."""
    if area_name == "Unknown" or pd.isna(area_name):
        return area_name, None, None

    lat, lon = fetch_lat_long(area_name)
    if lat is not None and lon is not None and is_within_dubai(lat, lon):
        print(f"Found valid coordinates for {area_name}: ({lat}, {lon})")
        return area_name, lat, lon

    print(f"No valid coordinates found for {area_name}")
    return area_name, None, None

def geocode_areas(dataframe):
    """Geocode all areas using multithreading."""
    areas = dataframe['area_en'].unique()
    print(f"Number of unique areas to geocode: {len(areas)}")

    with ThreadPoolExecutor(max_workers=10) as executor:
        results = list(executor.map(process_area, areas))

    geocoded_df = pd.DataFrame(results, columns=['area_en', 'latitude', 'longitude'])
    return geocoded_df

# Main Logic
geocoded_file = "geocoded_area_new.csv"

if os.path.exists(geocoded_file):
    print(f"Loading existing geocoded file: {geocoded_file}")
    geocoded_df = pd.read_csv(geocoded_file)
else:
    # Assuming sales_data is your main dataset; update this if different
    sales_data = pd.read_csv("../data/snp_dld_2024_transactions.csv")  # Replace with the actual path to your dataset
    geocoded_df = geocode_areas(sales_data)

    # Save the geocoded areas
    geocoded_df.to_csv(geocoded_file, index=False)
    print(f"Geocoded data saved to {geocoded_file}")

# Remaining missing coordinates
remaining_missing = geocoded_df[geocoded_df['latitude'].isnull() & geocoded_df['longitude'].isnull()]
print(f"\nNumber of areas with missing coordinates: {len(remaining_missing)}")
# Out:
# Number of unique areas to geocode: 273
# No valid coordinates found for SILICON OASIS
# Found valid coordinates for DUBAI MARITIME CITY: (25.262151, 55.26537042587559)
# Found valid coordinates for DUBAI CREEK HARBOUR: (25.197978, 55.36037960558315)
# Found valid coordinates for JUMEIRAH VILLAGE CIRCLE: (25.0527521, 55.205766331712184)
# Found valid coordinates for Al Wasl: (25.1959326, 55.2557371)
# No valid coordinates found for MEYDAN ONE
# No valid coordinates found for Wadi Al Safa 4
# No valid coordinates found for SUFOUH GARDENS
# No valid coordinates found for Madinat Al Mataar
# No valid coordinates found for MAJAN
# No valid coordinates found for TOWN SQUARE
# No valid coordinates found for Al Kifaf
# No valid coordinates found for BUSINESS BAY
# No valid coordinates found for Palm Deira
# No valid coordinates found for ARABIAN RANCHES III
# No valid coordinates found for Al Merkadh
# No valid coordinates found for Al Yufrah 1
# No valid coordinates found for SOBHA HEARTLAND
# No valid coordinates found for Um Suqaim Third
# No valid coordinates found for DUBAI HARBOUR
# No valid coordinates found for JUMEIRAH GOLF
# No valid coordinates found for ARJAN
# No valid coordinates found for DUBAI MARINA
# No valid coordinates found for Al Jadaf
# No valid coordinates found for Hadaeq Sheikh Mohammed Bin Rashid
# No valid coordinates found for BURJ KHALIFA
# No valid coordinates found for DUBAI STUDIO CITY
# No valid coordinates found for DUBAI HILLS
# No valid coordinates found for DUBAI HEALTHCARE CITY - PHASE 2
# No valid coordinates found for JUMEIRAH LAKES TOWERS
# No valid coordinates found for DUBAI PRODUCTION CITY
# No valid coordinates found for AL FURJAN
# No valid coordinates found for MBR DISTRICT 7
# No valid coordinates found for Al Hebiah Fourth
# No valid coordinates found for Al Aweer First
# No valid coordinates found for LIVING LEGENDS
# No valid coordinates found for Business Bay
# No valid coordinates found for Jabal Ali First
# No valid coordinates found for DUBAI WATER CANAL
# No valid coordinates found for VILLANOVA
# No valid coordinates found for Madinat Dubai Almelaheyah
# No valid coordinates found for JUMEIRAH VILLAGE TRIANGLE
# No valid coordinates found for Marsa Dubai
# Found valid coordinates for JADDAF WATERFRONT: (25.226831150000002, 55.33808609246107)
# No valid coordinates found for TECOM SITE A
# Found valid coordinates for Wadi Al Safa 3: (25.10571265, 55.316535293610826)
# No valid coordinates found for THE VALLEY
# No valid coordinates found for Al Yelayiss 2
# No valid coordinates found for DUBAI SPORTS CITY
# No valid coordinates found for Bukadra
# No valid coordinates found for PALM JUMEIRAH
# No valid coordinates found for MBR DISTRICT 1
# No valid coordinates found for Madinat Hind 4
# No valid coordinates found for Al Hebiah Sixth
# No valid coordinates found for DUBAI LAND RESIDENCE COMPLEX
# No valid coordinates found for THE WORLD
# No valid coordinates found for Warsan First
# No valid coordinates found for INTERNATIONAL CITY PH 2 & 3
# No valid coordinates found for Wadi Al Safa 2
# No valid coordinates found for THE FIELD
# No valid coordinates found for EMAAR SOUTH
# No valid coordinates found for Wadi Al Safa 7
# No valid coordinates found for LIWAN
# No valid coordinates found for MINA RASHID
# No valid coordinates found for Palm Jumeirah
# No valid coordinates found for Al Hebiah Fifth
# No valid coordinates found for Wadi Al Safa 5
# No valid coordinates found for DISCOVERY GARDENS
# No valid coordinates found for DAMAC HILLS
# No valid coordinates found for Jumeirah Third
# No valid coordinates found for DUBAI SCIENCE PARK
# No valid coordinates found for Dubai Investment Park First
# No valid coordinates found for CITY WALK
# No valid coordinates found for CHERRYWOODS
# No valid coordinates found for TILAL AL GHAF
# No valid coordinates found for NAD AL SHEBA GARDENS
# No valid coordinates found for DUBAI INVESTMENT PARK SECOND
# No valid coordinates found for Ras Al Khor Industrial First
# No valid coordinates found for ARABIAN RANCHES II
# No valid coordinates found for MOTOR CITY
# No valid coordinates found for DOWN TOWN JABAL ALI
# No valid coordinates found for Nad Al Shiba First
# No valid coordinates found for Al Mizhar First
# Found valid coordinates for Al Warqa Third: (25.190661, 55.4227553522109)
# No valid coordinates found for Trade Center First
# Found valid coordinates for DUBAI INDUSTRIAL CITY: (24.8399006, 55.0662934)
# No valid coordinates found for LA MER
# No valid coordinates found for BARSHA HEIGHTS
# No valid coordinates found for DUBAI DESIGN DISTRICT
# No valid coordinates found for REMRAAM
# No valid coordinates found for MEYDAN AVENUE
# No valid coordinates found for EMIRATE LIVING
# No valid coordinates found for THE VILLA
# No valid coordinates found for JUMEIRAH BEACH RESIDENCE
# No valid coordinates found for Mirdif
# No valid coordinates found for INTERNATIONAL CITY PH 1
# No valid coordinates found for Al Hamriya
# No valid coordinates found for Al Warqa First
# No valid coordinates found for THE GREENS
# No valid coordinates found for THE LAKES
# No valid coordinates found for DUBAI SOUTH
# No valid coordinates found for JABEL ALI HILLS
# No valid coordinates found for Al Mizhar Second
# No valid coordinates found for Al Barsha Third
# No valid coordinates found for AL KHAIL HEIGHTS
# No valid coordinates found for Al Goze First
# No valid coordinates found for AL BARARI
# No valid coordinates found for ARABIAN RANCHES I
# No valid coordinates found for Al Khawaneej First
# No valid coordinates found for SERENA
# No valid coordinates found for MUDON
# No valid coordinates found for Muhaisanah First
# No valid coordinates found for Al Thanyah Fifth
# No valid coordinates found for Al Muteena
# No valid coordinates found for Zaabeel First
# No valid coordinates found for BLUEWATERS
# No valid coordinates found for GRAND VIEWS
# No valid coordinates found for Zaabeel Second
# No valid coordinates found for Nad Al Hamar
# No valid coordinates found for RUKAN
# No valid coordinates found for Al Manara
# No valid coordinates found for MILLENNIUM
# No valid coordinates found for Al Twar Second
# No valid coordinates found for MIRA
# No valid coordinates found for Nad Al Shiba Third
# No valid coordinates found for Naif
# No valid coordinates found for PEARL JUMEIRA
# No valid coordinates found for Al Satwa
# No valid coordinates found for Port Saeed
# No valid coordinates found for Al Barsha First
# No valid coordinates found for Hor Al Anz
# No valid coordinates found for Jumeirah Second
# No valid coordinates found for JUMEIRAH LIVING
# No valid coordinates found for Al Garhoud
# No valid coordinates found for SAMA AL JADAF
# No valid coordinates found for Al Bada
# No valid coordinates found for JUMEIRA BAY
# No valid coordinates found for POLO TOWNHOUSES IGO
# No valid coordinates found for Al Rashidiya
# No valid coordinates found for Al Warqa Fourth
# No valid coordinates found for Eyal Nasser
# No valid coordinates found for Island 2
# No valid coordinates found for FALCON CITY OF WONDERS
# No valid coordinates found for JUMEIRAH PARK
# No valid coordinates found for JUMEIRAH ISLANDS
# No valid coordinates found for LIWAN 2
# No valid coordinates found for Um Suqaim First
# No valid coordinates found for ARABIAN RANCHES POLO CLUB
# No valid coordinates found for Al Barshaa South Second
# No valid coordinates found for JUMEIRAH HEIGHTS
# No valid coordinates found for Mankhool
# No valid coordinates found for DUBAI WATER FRONT
# No valid coordinates found for Al Barshaa South Third
# No valid coordinates found for Hor Al Anz East
# No valid coordinates found for Al Saffa Second
# No valid coordinates found for Al Karama
# No valid coordinates found for Ghadeer Al tair
# No valid coordinates found for Nad Al Shiba Fourth
# No valid coordinates found for Al Jafliya
# No valid coordinates found for Me'Aisem First
# No valid coordinates found for CITY OF ARABIA
# No valid coordinates found for Abu Hail
# No valid coordinates found for Al Mamzer
# No valid coordinates found for Al Kheeran
# No valid coordinates found for Al Suq Al Kabeer
# No valid coordinates found for MARSA AL ARAB
# No valid coordinates found for AL WAHA
# No valid coordinates found for SUSTAINABLE CITY
# No valid coordinates found for Jumeirah First
# No valid coordinates found for Um Suqaim Second
# No valid coordinates found for Al Barsha Second
# No valid coordinates found for Al Twar Fourth
# No valid coordinates found for Nad Al Shiba Second
# No valid coordinates found for Jabal Ali Industrial First
# No valid coordinates found for Al Waheda
# No valid coordinates found for Oud Al Muteena First
# No valid coordinates found for Muhaisanah Fourth
# No valid coordinates found for Al Mizhar Third
# No valid coordinates found for Al Rowaiyah Third
# No valid coordinates found for Al Warqa Second
# No valid coordinates found for Al Nahda First
# No valid coordinates found for Wadi Al Amardi
# No valid coordinates found for Al Eyas
# No valid coordinates found for Al Hudaiba
# No valid coordinates found for Palm Jabal Ali
# No valid coordinates found for Al Twar Third
# No valid coordinates found for Al Yelayiss 5
# No valid coordinates found for Al Aweer Second
# No valid coordinates found for Saih Shuaib 2
# No valid coordinates found for Al Qusais Second
# No valid coordinates found for Um Al Sheif
# No valid coordinates found for Nadd Hessa
# No valid coordinates found for Al Raffa
# No valid coordinates found for Al Nahda Second
# No valid coordinates found for DUBAI INVESTMENT PARK FIRST
# No valid coordinates found for Trade Center Second
# No valid coordinates found for Dubai Investment Park Second
# No valid coordinates found for AL Athbah
# No valid coordinates found for Madinat Hind 3
# No valid coordinates found for Me'Aisem Second
# No valid coordinates found for DUBAI GOLF CITY
# No valid coordinates found for HORIZON
# No valid coordinates found for Um Ramool
# No valid coordinates found for Hessyan First
# No valid coordinates found for Al Hebiah Third
# No valid coordinates found for Al Khawaneej Second
# No valid coordinates found for Al Barshaa South First
# No valid coordinates found for Al Goze Fourth
# No valid coordinates found for Al Thanyah Third
# No valid coordinates found for Saih Aldahal
# No valid coordinates found for Al Khabeesi
# No valid coordinates found for PALM DEIRA
# No valid coordinates found for Warsan Fourth
# No valid coordinates found for Al Goze Third
# No valid coordinates found for Dubai International Airport
# No valid coordinates found for Um Hurair First
# No valid coordinates found for Muhaisanah Third
# No valid coordinates found for Lehbab First
# No valid coordinates found for Al Mararr
# No valid coordinates found for Al Rega
# No valid coordinates found for Al Qusais First
# No valid coordinates found for MEDYAN RACE COURSE VILLAS
# No valid coordinates found for Ras Al Khor Industrial Second
# No valid coordinates found for Al Lusaily
# No valid coordinates found for Rega Al Buteen
# No valid coordinates found for Nad Shamma
# No valid coordinates found for Mushrif
# No valid coordinates found for Al Murqabat
# No valid coordinates found for Al Qusais Industrial Second
# No valid coordinates found for Al Warsan First
# No valid coordinates found for Saih Shuaib 4
# No valid coordinates found for Al Baraha
# No valid coordinates found for Al Ras
# No valid coordinates found for Al Twar First
# No valid coordinates found for Al Khairan First
# No valid coordinates found for PALMAROSA
# No valid coordinates found for DUBAI HEALTHCARE CITY - PHASE 1
# No valid coordinates found for Al Saffa First
# No valid coordinates found for Hessyan Second
# No valid coordinates found for Ras Al Khor Industrial Third
# No valid coordinates found for Lehbab Second
# No valid coordinates found for DMCC-EZ2
# No valid coordinates found for Madinat Latifa
# No valid coordinates found for Al Dhagaya
# No valid coordinates found for Al Goze Industrial Third
# No valid coordinates found for Al Qusais Industrial Fourth
# No valid coordinates found for Oud Metha
# No valid coordinates found for Al Ttay
# No valid coordinates found for DUBAI INTERNATIONAL ACADEMIC CITY
# No valid coordinates found for Al Qusais Industrial Third
# No valid coordinates found for Al Qusais Industrial First
# No valid coordinates found for Al Goze Industrial Second
# No valid coordinates found for Al Goze Industrial Fourth
# No valid coordinates found for Al Warsan Second
# No valid coordinates found for IBN BATTUTA
# No valid coordinates found for Jabal Ali
# No valid coordinates found for PALM JABAL ALI
# No valid coordinates found for Grayteesah
# No valid coordinates found for Al Goze Industrial First
# No valid coordinates found for Al Hebiah Second
# No valid coordinates found for Al Safouh First
# No valid coordinates found for Al Sabkha
# No valid coordinates found for Muhaisanah Second
# No valid coordinates found for Al Warsan Third
# No valid coordinates found for Muragab
# No valid coordinates found for DUBAI LIFESTYLE CITY
# No valid coordinates found for Al Buteen
# No valid coordinates found for Al Qusais Industrial Fifth
# No valid coordinates found for Saih Shuaib 1
# No valid coordinates found for Al Yelayiss 1
# No valid coordinates found for Mena Jabal Ali
# No valid coordinates found for Nazwah
# No valid coordinates found for Mugatrah
# Geocoded data saved to geocoded_area_new.csv
#
# Number of areas with missing coordinates: 265

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time

# Initialize geopy geolocator
geolocator = Nominatim(user_agent="geoapi", timeout=10)

# Define Dubai's geographic coordinate range
DUBAI_LAT_RANGE = (24.0, 26.5)
DUBAI_LON_RANGE = (54.0, 56.0)

def is_within_dubai(lat, lon):
    """Check if coordinates are within Dubai."""
    return DUBAI_LAT_RANGE[0] <= lat <= DUBAI_LAT_RANGE[1] and DUBAI_LON_RANGE[0] <= lon <= DUBAI_LON_RANGE[1]

def fetch_lat_long(location_name):
    """Fetch latitude and longitude for a location."""
    try:
        location = geolocator.geocode(location_name)
        if location:
            return location.latitude, location.longitude
    except Exception as e:
        print(f"Error fetching {location_name}: {e}")
    return None, None

def build_area_dict(dataframe):
    """Build a dictionary with area_en as keys and other location-related attributes as values."""
    grouped = dataframe.groupby('area_en').agg({
        'area_ar': lambda x: list(x.unique()),
        'project_name_en': lambda x: list(x.unique()),
        'project_name_ar': lambda x: list(x.unique()),
        'nearest_landmark_en': lambda x: list(x.unique()),
        'nearest_landmark_ar': lambda x: list(x.unique()),
        'nearest_metro_en': lambda x: list(x.unique()),
        'nearest_metro_ar': lambda x: list(x.unique()),
        'nearest_mall_en': lambda x: list(x.unique()),
        'nearest_mall_ar': lambda x: list(x.unique()),
        'master_project_en': lambda x: list(x.unique()),
        'master_project_ar': lambda x: list(x.unique()),
    }).reset_index()
    
    area_dict = {
        row['area_en']: (
            row['area_ar'], 
            row['project_name_en'], row['project_name_ar'], 
            row['nearest_landmark_en'], row['nearest_landmark_ar'], 
            row['nearest_metro_en'], row['nearest_metro_ar'], 
            row['nearest_mall_en'], row['nearest_mall_ar'], 
            row['master_project_en'], row['master_project_ar']
        )
        for _, row in grouped.iterrows()
    }
    return area_dict

def infer_coordinates(area_dict):
    """Infer coordinates for each area_en entry."""
    geocoded_results = {}
    
    for area_en, attributes in area_dict.items():
        if area_en == "Unknown":
            continue  # Skip 'Unknown' entries
        
        print(f"Processing {area_en}...")
        # Step 1: Try area_en
        lat, lon = fetch_lat_long(area_en)
        if lat and lon and is_within_dubai(lat, lon):
            geocoded_results[area_en] = (lat, lon)
            print(f"Found valid coordinates for {area_en} using area_en: ({lat}, {lon})")
            continue
        
        # Step 2: Try area_ar
        for area_ar in attributes[0]:
            lat, lon = fetch_lat_long(area_ar)
            if lat and lon and is_within_dubai(lat, lon):
                geocoded_results[area_en] = (lat, lon)
                print(f"Found valid coordinates for {area_en} using area_ar: ({lat}, {lon})")
                break
        if area_en in geocoded_results:
            continue

        # Step 3: Try project_name_en
        for project in attributes[1]:
            lat, lon = fetch_lat_long(project)
            if lat and lon and is_within_dubai(lat, lon):
                geocoded_results[area_en] = (lat, lon)
                print(f"Found valid coordinates for {area_en} using project_name_en: ({lat}, {lon})")
                break
        if area_en in geocoded_results:
            continue

        # Step 4: Try project_name_ar
        for project in attributes[2]:
            lat, lon = fetch_lat_long(project)
            if lat and lon and is_within_dubai(lat, lon):
                geocoded_results[area_en] = (lat, lon)
                print(f"Found valid coordinates for {area_en} using project_name_ar: ({lat}, {lon})")
                break
        if area_en in geocoded_results:
            continue

        # Step 5: Try nearest_landmark_en
        for landmark in attributes[3]:
            lat, lon = fetch_lat_long(landmark)
            if lat and lon and is_within_dubai(lat, lon):
                geocoded_results[area_en] = (lat, lon)
                print(f"Found valid coordinates for {area_en} using nearest_landmark_en: ({lat}, {lon})")
                break
        if area_en in geocoded_results:
            continue

        # Step 6: Try nearest_landmark_ar
        for landmark in attributes[4]:
            lat, lon = fetch_lat_long(landmark)
            if lat and lon and is_within_dubai(lat, lon):
                geocoded_results[area_en] = (lat, lon)
                print(f"Found valid coordinates for {area_en} using nearest_landmark_ar: ({lat}, {lon})")
                break
        if area_en in geocoded_results:
            continue

        # Step 7: Try other location fields (nearest_metro, mall, etc.)
        for field in attributes[5:]:
            for location in field:
                lat, lon = fetch_lat_long(location)
                if lat and lon and is_within_dubai(lat, lon):
                    geocoded_results[area_en] = (lat, lon)
                    print(f"Found valid coordinates for {area_en} using {location}: ({lat}, {lon})")
                    break
            if area_en in geocoded_results:
                break
        
        if area_en not in geocoded_results:
            print(f"Could not find valid coordinates for {area_en}")
        
        # Respect API rate limits
        time.sleep(1)

    return geocoded_results

# Main logic
# Load your dataset
sales_data = pd.read_csv("../data/snp_dld_2024_transactions.csv")  # Replace with your dataset's path
area_dict = build_area_dict(sales_data)
geocoded_results = infer_coordinates(area_dict)

# Save the results
geocoded_df = pd.DataFrame.from_dict(geocoded_results, orient='index', columns=['latitude', 'longitude'])
geocoded_df.reset_index(inplace=True)
geocoded_df.rename(columns={'index': 'area_en'}, inplace=True)
geocoded_df.to_csv("geocoded_area_new.csv", index=False)
print("Geocoding completed and saved to geocoded_area_new.csv")
# Out:
# Processing AL Athbah...
# Could not find valid coordinates for AL Athbah
# Processing AL BARARI...
# Found valid coordinates for AL BARARI using area_en: (25.118865, 55.3209685)
# Processing AL FURJAN...
# Found valid coordinates for AL FURJAN using area_en: (25.0304736, 55.1522307)
# Processing AL KHAIL HEIGHTS...
# Found valid coordinates for AL KHAIL HEIGHTS using area_en: (25.155860150000002, 55.2536875439334)
# Processing AL WAHA...
# Could not find valid coordinates for AL WAHA
# Processing ARABIAN RANCHES I...
# Found valid coordinates for ARABIAN RANCHES I using area_en: (25.04875135, 55.267288518151844)
# Processing ARABIAN RANCHES II...
# Found valid coordinates for ARABIAN RANCHES II using area_en: (25.03439685, 55.27332788354515)
# Processing ARABIAN RANCHES III...
# Found valid coordinates for ARABIAN RANCHES III using nearest_landmark_en: (25.051092949999997, 55.31808411322436)
# Processing ARABIAN RANCHES POLO CLUB...
# Found valid coordinates for ARABIAN RANCHES POLO CLUB using area_en: (25.037414249999998, 55.25395447616396)
# Processing ARJAN...
# Found valid coordinates for ARJAN using project_name_en: (25.0567785, 55.23637449799419)
# Processing Abu Hail...
# Found valid coordinates for Abu Hail using area_en: (25.2860287, 55.328865)
# Processing Al Aweer First...
# Could not find valid coordinates for Al Aweer First
# Processing Al Aweer Second...
# Could not find valid coordinates for Al Aweer Second
# Processing Al Bada...
# Found valid coordinates for Al Bada using nearest_landmark_en: (25.197033599999997, 55.27413294647308)
# Processing Al Baraha...
# Found valid coordinates for Al Baraha using area_en: (25.2809884, 55.3195255)
# Processing Al Barsha First...
# Found valid coordinates for Al Barsha First using area_en: (25.1071127, 55.1984575)
# Processing Al Barsha Second...
# Found valid coordinates for Al Barsha Second using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Barsha Third...
# Found valid coordinates for Al Barsha Third using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Barshaa South First...
# Found valid coordinates for Al Barshaa South First using nearest_landmark_ar: (25.0423709, 55.2416609)
# Processing Al Barshaa South Second...
# Found valid coordinates for Al Barshaa South Second using nearest_landmark_ar: (25.0423709, 55.2416609)
# Processing Al Barshaa South Third...
# Found valid coordinates for Al Barshaa South Third using nearest_landmark_ar: (25.0423709, 55.2416609)
# Processing Al Buteen...
# Found valid coordinates for Al Buteen using area_en: (25.2595231, 55.3195095)
# Processing Al Dhagaya...
# Found valid coordinates for Al Dhagaya using area_en: (25.2726408, 55.3002405)
# Processing Al Eyas...
# Found valid coordinates for Al Eyas using area_ar: (25.2113092, 55.5377768)
# Processing Al Garhoud...
# Found valid coordinates for Al Garhoud using area_en: (25.2407367, 55.3520393)
# Processing Al Goze First...
# Found valid coordinates for Al Goze First using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Al Goze Fourth...
# Found valid coordinates for Al Goze Fourth using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Al Goze Industrial First...
# Found valid coordinates for Al Goze Industrial First using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Goze Industrial Fourth...
# Found valid coordinates for Al Goze Industrial Fourth using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Goze Industrial Second...
# Found valid coordinates for Al Goze Industrial Second using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Goze Industrial Third...
# Found valid coordinates for Al Goze Industrial Third using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Goze Third...
# Found valid coordinates for Al Goze Third using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Al Hamriya...
# Found valid coordinates for Al Hamriya using area_en: (25.2599297, 55.3031938)
# Processing Al Hebiah Fifth...
# Could not find valid coordinates for Al Hebiah Fifth
# Processing Al Hebiah Fourth...
# Could not find valid coordinates for Al Hebiah Fourth
# Processing Al Hebiah Second...
# Could not find valid coordinates for Al Hebiah Second
# Processing Al Hebiah Sixth...
# Could not find valid coordinates for Al Hebiah Sixth
# Processing Al Hebiah Third...
# Could not find valid coordinates for Al Hebiah Third
# Processing Al Hudaiba...
# Found valid coordinates for Al Hudaiba using area_en: (25.2428328, 55.279212)
# Processing Al Jadaf...
# Found valid coordinates for Al Jadaf using area_en: (25.2249103, 55.3337479)
# Processing Al Jafliya...
# Found valid coordinates for Al Jafliya using area_en: (25.216522, 55.2644949)
# Processing Al Karama...
# Found valid coordinates for Al Karama using area_en: (25.2482136, 55.3050609)
# Processing Al Khabeesi...
# Found valid coordinates for Al Khabeesi using area_en: (25.26610755, 55.327714764160746)
# Processing Al Khairan First...
# Found valid coordinates for Al Khairan First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Khawaneej First...
# Found valid coordinates for Al Khawaneej First using City Centre Mirdif: (25.2173429, 55.4071287)
# Processing Al Khawaneej Second...
# Found valid coordinates for Al Khawaneej Second using City Centre Mirdif: (25.2173429, 55.4071287)
# Processing Al Kheeran...
# Found valid coordinates for Al Kheeran using area_en: (24.44418755, 54.45712945710038)
# Processing Al Kifaf...
# Found valid coordinates for Al Kifaf using area_en: (25.2346273, 55.298597312379904)
# Processing Al Lusaily...
# Found valid coordinates for Al Lusaily using area_ar: (24.4330113, 54.5496199)
# Processing Al Mamzer...
# Found valid coordinates for Al Mamzer using area_ar: (25.3005332, 55.3596332)
# Processing Al Manara...
# Found valid coordinates for Al Manara using area_ar: (25.1448185, 55.2144527)
# Processing Al Mararr...
# Found valid coordinates for Al Mararr using area_ar: (25.2766379, 55.3089094)
# Processing Al Merkadh...
# Found valid coordinates for Al Merkadh using area_ar: (25.169213, 55.2924727)
# Processing Al Mizhar First...
# Found valid coordinates for Al Mizhar First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Mizhar Second...
# Found valid coordinates for Al Mizhar Second using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Mizhar Third...
# Found valid coordinates for Al Mizhar Third using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Murqabat...
# Found valid coordinates for Al Murqabat using area_ar: (25.2655388, 55.3225135)
# Processing Al Muteena...
# Found valid coordinates for Al Muteena using area_en: (25.2700926, 55.3106648)
# Processing Al Nahda First...
# Found valid coordinates for Al Nahda First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Nahda Second...
# Found valid coordinates for Al Nahda Second using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Qusais First...
# Found valid coordinates for Al Qusais First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Qusais Industrial Fifth...
# Found valid coordinates for Al Qusais Industrial Fifth using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Qusais Industrial First...
# Found valid coordinates for Al Qusais Industrial First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Qusais Industrial Fourth...
# Found valid coordinates for Al Qusais Industrial Fourth using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Qusais Industrial Second...
# Found valid coordinates for Al Qusais Industrial Second using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Qusais Industrial Third...
# Found valid coordinates for Al Qusais Industrial Third using area_en: (25.3260017, 55.4331454)
# Processing Al Qusais Second...
# Found valid coordinates for Al Qusais Second using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Raffa...
# Found valid coordinates for Al Raffa using area_en: (25.2542057, 55.2879667)
# Processing Al Ras...
# Found valid coordinates for Al Ras using area_en: (25.2687742, 55.2936231)
# Processing Al Rashidiya...
# Found valid coordinates for Al Rashidiya using area_en: (25.222025, 55.3910064)
# Processing Al Rega...
# Found valid coordinates for Al Rega using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Rowaiyah Third...
# Could not find valid coordinates for Al Rowaiyah Third
# Processing Al Sabkha...
# Found valid coordinates for Al Sabkha using area_en: (25.2692256, 55.3024936)
# Processing Al Saffa First...
# Found valid coordinates for Al Saffa First using nearest_landmark_en: (25.197033599999997, 55.27413294647308)
# Processing Al Saffa Second...
# Found valid coordinates for Al Saffa Second using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Safouh First...
# Found valid coordinates for Al Safouh First using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Al Satwa...
# Found valid coordinates for Al Satwa using area_en: (25.2208602, 55.2737617)
# Processing Al Suq Al Kabeer...
# Found valid coordinates for Al Suq Al Kabeer using area_en: (25.2639134044859, 55.29226263640029)
# Processing Al Thanyah Fifth...
# Could not find valid coordinates for Al Thanyah Fifth
# Processing Al Thanyah Third...
# Found valid coordinates for Al Thanyah Third using project_name_en: (25.082107885888746, 55.17303192330879)
# Processing Al Ttay...
# Found valid coordinates for Al Ttay using area_en: (25.2321563, 55.5563174)
# Processing Al Twar First...
# Found valid coordinates for Al Twar First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Twar Fourth...
# Found valid coordinates for Al Twar Fourth using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Twar Second...
# Found valid coordinates for Al Twar Second using area_en: (25.27122485, 55.364130332632215)
# Processing Al Twar Third...
# Found valid coordinates for Al Twar Third using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Waheda...
# Found valid coordinates for Al Waheda using area_en: (25.2915387, 55.3373622)
# Processing Al Warqa First...
# Found valid coordinates for Al Warqa First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Warqa Fourth...
# Found valid coordinates for Al Warqa Fourth using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Warqa Second...
# Found valid coordinates for Al Warqa Second using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Al Warqa Third...
# Found valid coordinates for Al Warqa Third using area_en: (25.190661, 55.4227553522109)
# Processing Al Warsan First...
# Could not find valid coordinates for Al Warsan First
# Processing Al Warsan Second...
# Found valid coordinates for Al Warsan Second using Rashidiya Metro Station: (25.2295959, 55.3914898)
# Processing Al Warsan Third...
# Could not find valid coordinates for Al Warsan Third
# Processing Al Wasl...
# Found valid coordinates for Al Wasl using area_en: (25.1959326, 55.2557371)
# Processing Al Yelayiss 1...
# Found valid coordinates for Al Yelayiss 1 using area_ar: (25.0164904, 55.3111582)
# Processing Al Yelayiss 2...
# Found valid coordinates for Al Yelayiss 2 using area_ar: (24.9982628, 55.2867437907612)
# Processing Al Yelayiss 5...
# Found valid coordinates for Al Yelayiss 5 using area_ar: (24.9707278, 55.265407)
# Processing Al Yufrah 1...
# Found valid coordinates for Al Yufrah 1 using area_en: (25.0029883, 55.4387395)
# Processing BARSHA HEIGHTS...
# Found valid coordinates for BARSHA HEIGHTS using area_en: (25.0982842, 55.1757823)
# Processing BLUEWATERS...
# Found valid coordinates for BLUEWATERS using area_en: (25.07954805, 55.12170421845323)
# Processing BURJ KHALIFA...
# Found valid coordinates for BURJ KHALIFA using area_en: (25.197033599999997, 55.27413294647308)
# Processing BUSINESS BAY...
# Found valid coordinates for BUSINESS BAY using area_en: (25.18942655, 55.26481901527489)
# Processing Bukadra...
# Found valid coordinates for Bukadra using area_en: (25.1765148, 55.3257751)
# Processing Business Bay...
# Found valid coordinates for Business Bay using area_en: (25.18942655, 55.26481901527489)
# Processing CHERRYWOODS...
# Found valid coordinates for CHERRYWOODS using area_en: (25.016004449999997, 55.2909518531374)
# Processing CITY OF ARABIA...
# Found valid coordinates for CITY OF ARABIA using area_en: (25.0924395, 55.336933)
# Processing CITY WALK...
# Found valid coordinates for CITY WALK using area_en: (25.2081589, 55.26187365641171)
# Processing DAMAC HILLS...
# Found valid coordinates for DAMAC HILLS using area_en: (25.0264384, 55.251228)
# Processing DISCOVERY GARDENS...
# Found valid coordinates for DISCOVERY GARDENS using area_en: (25.0352571, 55.1454134)
# Processing DMCC-EZ2...
# Found valid coordinates for DMCC-EZ2 using area_ar: (25.0708766, 55.1387113)
# Processing DOWN TOWN JABAL ALI...
# Found valid coordinates for DOWN TOWN JABAL ALI using nearest_landmark_en: (24.966807, 55.15825718982431)
# Processing DUBAI CREEK HARBOUR...
# Found valid coordinates for DUBAI CREEK HARBOUR using area_en: (25.197978, 55.36037960558315)
# Processing DUBAI DESIGN DISTRICT...
# Found valid coordinates for DUBAI DESIGN DISTRICT using area_en: (25.188132, 55.29744343116474)
# Processing DUBAI GOLF CITY...
# Found valid coordinates for DUBAI GOLF CITY using area_en: (25.01130525, 55.23426739724147)
# Processing DUBAI HARBOUR...
# Found valid coordinates for DUBAI HARBOUR using area_en: (25.095618799999997, 55.13800090659106)
# Processing DUBAI HEALTHCARE CITY - PHASE 1...
# Found valid coordinates for DUBAI HEALTHCARE CITY - PHASE 1 using area_en: (25.23181945, 55.32250393537943)
# Processing DUBAI HEALTHCARE CITY - PHASE 2...
# Found valid coordinates for DUBAI HEALTHCARE CITY - PHASE 2 using area_en: (25.23181945, 55.32250393537943)
# Processing DUBAI HILLS...
# Found valid coordinates for DUBAI HILLS using area_en: (25.0974142, 55.2684401)
# Processing DUBAI INDUSTRIAL CITY...
# Found valid coordinates for DUBAI INDUSTRIAL CITY using area_en: (24.8399006, 55.0662934)
# Processing DUBAI INTERNATIONAL ACADEMIC CITY...
# Found valid coordinates for DUBAI INTERNATIONAL ACADEMIC CITY using area_en: (25.107765800000003, 55.401610732905894)
# Processing DUBAI INVESTMENT PARK FIRST...
# Found valid coordinates for DUBAI INVESTMENT PARK FIRST using nearest_landmark_en: (24.966807, 55.15825718982431)
# Processing DUBAI INVESTMENT PARK SECOND...
# Found valid coordinates for DUBAI INVESTMENT PARK SECOND using area_en: (24.98204425, 55.1964194133587)
# Processing DUBAI LAND RESIDENCE COMPLEX...
# Found valid coordinates for DUBAI LAND RESIDENCE COMPLEX using area_en: (25.0853591, 55.382978)
# Processing DUBAI LIFESTYLE CITY...
# Found valid coordinates for DUBAI LIFESTYLE CITY using area_en: (25.04260265, 55.28216284609378)
# Processing DUBAI MARINA...
# Found valid coordinates for DUBAI MARINA using area_en: (25.0786415, 55.1352524)
# Processing DUBAI MARITIME CITY...
# Found valid coordinates for DUBAI MARITIME CITY using area_en: (25.262151, 55.26537042587559)
# Processing DUBAI PRODUCTION CITY...
# Found valid coordinates for DUBAI PRODUCTION CITY using area_en: (25.032132400000002, 55.191307014071384)
# Processing DUBAI SCIENCE PARK...
# Found valid coordinates for DUBAI SCIENCE PARK using area_en: (25.068451596904335, 55.245708496699365)
# Processing DUBAI SOUTH...
# Found valid coordinates for DUBAI SOUTH using area_en: (24.9144391, 55.1615128)
# Processing DUBAI SPORTS CITY...
# Found valid coordinates for DUBAI SPORTS CITY using area_en: (25.0321379, 55.219353)
# Processing DUBAI STUDIO CITY...
# Found valid coordinates for DUBAI STUDIO CITY using area_en: (25.0415641, 55.2522587)
# Processing DUBAI WATER CANAL...
# Found valid coordinates for DUBAI WATER CANAL using area_en: (25.1884394, 55.2473226)
# Processing DUBAI WATER FRONT...
# Found valid coordinates for DUBAI WATER FRONT using nearest_landmark_en: (24.9198548, 55.00868)
# Processing Dubai International Airport...
# Found valid coordinates for Dubai International Airport using area_en: (25.2521287, 55.365715576690505)
# Processing Dubai Investment Park First...
# Could not find valid coordinates for Dubai Investment Park First
# Processing Dubai Investment Park Second...
# Found valid coordinates for Dubai Investment Park Second using area_en: (24.98204425, 55.1964194133587)
# Processing EMAAR SOUTH...
# Found valid coordinates for EMAAR SOUTH using area_en: (24.8649069, 55.14376334914999)
# Processing EMIRATE LIVING...
# Found valid coordinates for EMIRATE LIVING using area_ar: (25.0639869, 55.1645849)
# Processing Eyal Nasser...
# Found valid coordinates for Eyal Nasser using area_ar: (25.2743483, 55.3041029)
# Processing FALCON CITY OF WONDERS...
# Found valid coordinates for FALCON CITY OF WONDERS using area_en: (25.0955281, 55.3393384)
# Processing GRAND VIEWS...
# Found valid coordinates for GRAND VIEWS using area_en: (25.1456862, 55.300144314906376)
# Processing Ghadeer Al tair...
# Found valid coordinates for Ghadeer Al tair using area_en: (25.1509135, 55.2720063)
# Processing Grayteesah...
# Found valid coordinates for Grayteesah using area_en: (24.87115215, 55.5072782974985)
# Processing HORIZON...
# Found valid coordinates for HORIZON using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Hadaeq Sheikh Mohammed Bin Rashid...
# Found valid coordinates for Hadaeq Sheikh Mohammed Bin Rashid using area_en: (25.119016594266267, 55.26187658505671)
# Processing Hessyan First...
# Could not find valid coordinates for Hessyan First
# Processing Hessyan Second...
# Could not find valid coordinates for Hessyan Second
# Processing Hor Al Anz...
# Found valid coordinates for Hor Al Anz using area_en: (25.2822545, 55.348484)
# Processing Hor Al Anz East...
# Found valid coordinates for Hor Al Anz East using area_en: (25.2822545, 55.348484)
# Processing IBN BATTUTA ...
# Found valid coordinates for IBN BATTUTA  using area_en: (25.0466788, 55.1174939)
# Processing INTERNATIONAL CITY PH 1...
# Found valid coordinates for INTERNATIONAL CITY PH 1 using project_name_en: (25.1550149, 55.2343471)
# Processing INTERNATIONAL CITY PH 2 & 3...
# Found valid coordinates for INTERNATIONAL CITY PH 2 & 3 using area_en: (25.1316312, 55.38673493715861)
# Processing Island 2...
# Found valid coordinates for Island 2 using area_ar: (24.3815383, 54.6913221)
# Processing JABEL ALI HILLS...
# Found valid coordinates for JABEL ALI HILLS using nearest_landmark_en: (24.9198548, 55.00868)
# Processing JADDAF WATERFRONT...
# Found valid coordinates for JADDAF WATERFRONT using area_en: (25.226831150000002, 55.33808609246107)
# Processing JUMEIRA BAY...
# Found valid coordinates for JUMEIRA BAY using area_ar: (25.2136677, 55.2365845)
# Processing JUMEIRAH BEACH RESIDENCE...
# Found valid coordinates for JUMEIRAH BEACH RESIDENCE using area_en: (25.0778021, 55.13518094856796)
# Processing JUMEIRAH GOLF...
# Found valid coordinates for JUMEIRAH GOLF using area_en: (25.0177925, 55.1633352)
# Processing JUMEIRAH HEIGHTS...
# Found valid coordinates for JUMEIRAH HEIGHTS using area_en: (25.06553675, 55.14557004705467)
# Processing JUMEIRAH ISLANDS...
# Found valid coordinates for JUMEIRAH ISLANDS using area_en: (25.0570585, 55.15614637904315)
# Processing JUMEIRAH LAKES TOWERS...
# Found valid coordinates for JUMEIRAH LAKES TOWERS using area_en: (25.07238315, 55.14374317909845)
# Processing JUMEIRAH LIVING...
# Found valid coordinates for JUMEIRAH LIVING using area_en: (25.0875891, 55.1471081)
# Processing JUMEIRAH PARK...
# Found valid coordinates for JUMEIRAH PARK using area_en: (25.0469412, 55.15481775751905)
# Processing JUMEIRAH VILLAGE CIRCLE...
# Found valid coordinates for JUMEIRAH VILLAGE CIRCLE using area_en: (25.0527521, 55.205766331712184)
# Processing JUMEIRAH VILLAGE TRIANGLE...
# Found valid coordinates for JUMEIRAH VILLAGE TRIANGLE using area_en: (25.0498433, 55.1907008)
# Processing Jabal Ali...
# Found valid coordinates for Jabal Ali using area_en: (25.0578769, 55.1273617)
# Processing Jabal Ali First...
# Found valid coordinates for Jabal Ali First using project_name_en: (25.02836415, 55.1438277178559)
# Processing Jabal Ali Industrial First...
# Found valid coordinates for Jabal Ali Industrial First using area_en: (24.982860074634765, 55.11508202845593)
# Processing Jumeirah First...
# Found valid coordinates for Jumeirah First using nearest_landmark_en: (25.197033599999997, 55.27413294647308)
# Processing Jumeirah Second...
# Found valid coordinates for Jumeirah Second using project_name_ar: (24.327962300000003, 54.53732275)
# Processing Jumeirah Third...
# Found valid coordinates for Jumeirah Third using nearest_landmark_en: (25.197033599999997, 55.27413294647308)
# Processing LA MER...
# Found valid coordinates for LA MER using nearest_landmark_en: (25.197033599999997, 55.27413294647308)
# Processing LIVING LEGENDS...
# Found valid coordinates for LIVING LEGENDS using area_en: (25.0850789, 55.2981217)
# Processing LIWAN...
# Could not find valid coordinates for LIWAN
# Processing LIWAN 2...
# Could not find valid coordinates for LIWAN 2
# Processing Lehbab First...
# Could not find valid coordinates for Lehbab First
# Processing Lehbab Second...
# Could not find valid coordinates for Lehbab Second
# Processing MAJAN...
# Found valid coordinates for MAJAN using area_ar: (25.0929388, 55.3184835)
# Processing MARSA AL ARAB...
# Found valid coordinates for MARSA AL ARAB using area_en: (25.144379299999997, 55.18950369674157)
# Processing MBR DISTRICT 1...
# Found valid coordinates for MBR DISTRICT 1 using project_name_en: (25.16446002330713, 55.27433999415931)
# Processing MBR DISTRICT 7...
# Found valid coordinates for MBR DISTRICT 7 using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing MEDYAN RACE COURSE VILLAS...
# Found valid coordinates for MEDYAN RACE COURSE VILLAS using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing MEYDAN AVENUE...
# Found valid coordinates for MEYDAN AVENUE using area_en: (25.15913045, 55.29614386605405)
# Processing MEYDAN ONE...
# Found valid coordinates for MEYDAN ONE using area_en: (25.1725019, 55.28710370781371)
# Processing MILLENNIUM...
# Found valid coordinates for MILLENNIUM using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing MINA RASHID...
# Found valid coordinates for MINA RASHID using area_en: (25.2600528, 55.2751074)
# Processing MIRA...
# Found valid coordinates for MIRA using area_ar: (25.00866025, 55.30553609890601)
# Processing MOTOR CITY...
# Found valid coordinates for MOTOR CITY using project_name_en: (25.04299545, 55.24316511339241)
# Processing MUDON...
# Found valid coordinates for MUDON using area_ar: (25.0204108, 55.2679936)
# Processing Madinat Al Mataar...
# Found valid coordinates for Madinat Al Mataar using area_en: (24.890272, 55.1428455)
# Processing Madinat Dubai Almelaheyah...
# Found valid coordinates for Madinat Dubai Almelaheyah using area_ar: (25.2496256, 55.276165)
# Processing Madinat Hind 3...
# Error fetching Madinat Hind 3: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Madinat+Hind+3&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7192ddf72310>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error fetching مدينة هند 3: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%D9%85%D8%AF%D9%8A%D9%86%D8%A9+%D9%87%D9%86%D8%AF+3&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7192ddf74220>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error fetching nan: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=nan&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7192ddf74d30>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Could not find valid coordinates for Madinat Hind 3
# Processing Madinat Hind 4...
# Found valid coordinates for Madinat Hind 4 using area_en: (25.0077507, 55.3637056)
# Processing Madinat Latifa...
# Found valid coordinates for Madinat Latifa using area_en: (24.8990386, 55.2785861)
# Processing Mankhool...
# Found valid coordinates for Mankhool using area_en: (25.251801, 55.29777548332489)
# Processing Marsa Dubai...
# Found valid coordinates for Marsa Dubai using area_en: (25.23116035, 55.34646274347939)
# Processing Me'Aisem First...
# Found valid coordinates for Me'Aisem First using project_name_en: (25.0771249, 55.135842)
# Processing Me'Aisem Second...
# Could not find valid coordinates for Me'Aisem Second
# Processing Mena Jabal Ali...
# Found valid coordinates for Mena Jabal Ali using area_ar: (24.9804578, 55.0598883)
# Processing Mirdif...
# Found valid coordinates for Mirdif using area_en: (25.2150727, 55.4089036)
# Processing Mugatrah...
# Found valid coordinates for Mugatrah using area_en: (24.7923464, 55.1951843)
# Processing Muhaisanah First...
# Found valid coordinates for Muhaisanah First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Muhaisanah Fourth...
# Found valid coordinates for Muhaisanah Fourth using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Muhaisanah Second...
# Found valid coordinates for Muhaisanah Second using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Muhaisanah Third...
# Found valid coordinates for Muhaisanah Third using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Muragab...
# Could not find valid coordinates for Muragab
# Processing Mushrif...
# Found valid coordinates for Mushrif using area_en: (25.2142599, 55.4506587)
# Processing NAD AL SHEBA GARDENS...
# Found valid coordinates for NAD AL SHEBA GARDENS using area_en: (25.165965200000002, 55.307881779331815)
# Processing Nad Al Hamar...
# Found valid coordinates for Nad Al Hamar using area_en: (25.228071653517837, 55.37735286826692)
# Processing Nad Al Shiba First...
# Found valid coordinates for Nad Al Shiba First using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Nad Al Shiba Fourth...
# Found valid coordinates for Nad Al Shiba Fourth using City Centre Mirdif: (25.2173429, 55.4071287)
# Processing Nad Al Shiba Second...
# Found valid coordinates for Nad Al Shiba Second using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Nad Al Shiba Third...
# Found valid coordinates for Nad Al Shiba Third using Rashidiya Metro Station: (25.2295959, 55.3914898)
# Processing Nad Shamma...
# Found valid coordinates for Nad Shamma using area_en: (25.2177763, 55.383843504527334)
# Processing Nadd Hessa...
# Found valid coordinates for Nadd Hessa using area_en: (25.1219309, 55.3850506)
# Processing Naif...
# Found valid coordinates for Naif using area_ar: (25.2719386, 55.3101673)
# Processing Nazwah...
# Found valid coordinates for Nazwah using area_en: (25.01878065, 55.645710625367485)
# Processing Oud Al Muteena First...
# Found valid coordinates for Oud Al Muteena First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Oud Metha...
# Found valid coordinates for Oud Metha using area_en: (25.2439301, 55.3158939)
# Processing PALM DEIRA...
# Found valid coordinates for PALM DEIRA using area_en: (25.2761408, 55.3016752)
# Processing PALM JABAL ALI...
# Found valid coordinates for PALM JABAL ALI using area_en: (24.9876012, 55.02200636687711)
# Processing PALM JUMEIRAH...
# Found valid coordinates for PALM JUMEIRAH using area_en: (25.1180879, 55.1342009)
# Processing PALMAROSA...
# Found valid coordinates for PALMAROSA using nearest_landmark_ar: (25.0423709, 55.2416609)
# Processing PEARL JUMEIRA...
# Found valid coordinates for PEARL JUMEIRA using area_en: (25.244473999999997, 55.25895972097338)
# Processing POLO TOWNHOUSES IGO...
# Found valid coordinates for POLO TOWNHOUSES IGO using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Palm Deira...
# Found valid coordinates for Palm Deira using area_en: (25.2761408, 55.3016752)
# Processing Palm Jabal Ali...
# Found valid coordinates for Palm Jabal Ali using area_en: (24.9876012, 55.02200636687711)
# Processing Palm Jumeirah...
# Found valid coordinates for Palm Jumeirah using area_en: (25.1180879, 55.1342009)
# Processing Port Saeed...
# Found valid coordinates for Port Saeed using area_en: (25.2604609, 55.3296278)
# Processing REMRAAM...
# Found valid coordinates for REMRAAM using area_en: (25.0013542, 55.24885632771925)
# Processing RUKAN...
# Found valid coordinates for RUKAN using project_name_en: (25.0423484, 55.288092974772134)
# Processing Ras Al Khor Industrial First...
# Found valid coordinates for Ras Al Khor Industrial First using area_en: (25.1797722, 55.3345395)
# Processing Ras Al Khor Industrial Second...
# Found valid coordinates for Ras Al Khor Industrial Second using nearest_landmark_en: (25.19475815, 55.27805910442858)
# Processing Ras Al Khor Industrial Third...
# Found valid coordinates for Ras Al Khor Industrial Third using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Rega Al Buteen...
# Found valid coordinates for Rega Al Buteen using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing SAMA AL JADAF...
# Found valid coordinates for SAMA AL JADAF using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing SERENA...
# Found valid coordinates for SERENA using area_ar: (25.035380449999998, 55.28590440039767)
# Processing SILICON OASIS...
# Found valid coordinates for SILICON OASIS using area_ar: (25.1137625, 55.3721899)
# Processing SOBHA HEARTLAND...
# Found valid coordinates for SOBHA HEARTLAND using project_name_en: (25.179814800000003, 55.3053438493996)
# Processing SUFOUH GARDENS...
# Found valid coordinates for SUFOUH GARDENS using area_en: (25.1101377, 55.1785377)
# Processing SUSTAINABLE CITY...
# Found valid coordinates for SUSTAINABLE CITY using area_en: (25.032258849999998, 55.2796822756265)
# Processing Saih Aldahal...
# Found valid coordinates for Saih Aldahal using area_ar: (24.7450428, 55.36193205295207)
# Processing Saih Shuaib 1...
# Found valid coordinates for Saih Shuaib 1 using area_en: (24.9024228, 55.0059684)
# Processing Saih Shuaib 2...
# Found valid coordinates for Saih Shuaib 2 using area_en: (24.8578572, 55.0608716)
# Processing Saih Shuaib 4...
# Found valid coordinates for Saih Shuaib 4 using area_en: (24.8238246, 55.0971343)
# Processing TECOM SITE A...
# Found valid coordinates for TECOM SITE A using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing THE FIELD...
# Could not find valid coordinates for THE FIELD
# Processing THE GREENS...
# Found valid coordinates for THE GREENS using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing THE LAKES...
# Found valid coordinates for THE LAKES using project_name_en: (25.07919141426034, 55.172900775354115)
# Processing THE VALLEY...
# Could not find valid coordinates for THE VALLEY
# Processing THE VILLA...
# Found valid coordinates for THE VILLA using area_ar: (25.218984650000003, 55.4491965052065)
# Processing THE WORLD...
# Found valid coordinates for THE WORLD using area_en: (25.237267850000002, 55.195494157283456)
# Processing TILAL AL GHAF...
# Found valid coordinates for TILAL AL GHAF using area_en: (25.02426745, 55.22382996438196)
# Processing TOWN SQUARE...
# Found valid coordinates for TOWN SQUARE using project_name_en: (25.013115300000003, 55.287024260537194)
# Processing Trade Center First...
# Found valid coordinates for Trade Center First using area_en: (25.2299822, 55.2865869)
# Processing Trade Center Second...
# Found valid coordinates for Trade Center Second using nearest_landmark_en: (25.197033599999997, 55.27413294647308)
# Processing Um Al Sheif...
# Found valid coordinates for Um Al Sheif using area_ar: (25.1319978, 55.204668)
# Processing Um Hurair First...
# Found valid coordinates for Um Hurair First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Um Ramool...
# Found valid coordinates for Um Ramool using area_en: (25.2310318, 55.3674888)
# Processing Um Suqaim First...
# Found valid coordinates for Um Suqaim First using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Um Suqaim Second...
# Found valid coordinates for Um Suqaim Second using nearest_landmark_en: (25.141327099999998, 55.18539672753495)
# Processing Um Suqaim Third...
# Found valid coordinates for Um Suqaim Third using project_name_en: (25.4175531, 55.4504881)
# Processing VILLANOVA...
# Found valid coordinates for VILLANOVA using area_ar: (25.0750041, 55.359536097226105)
# Processing Wadi Al Amardi...
# Found valid coordinates for Wadi Al Amardi using area_en: (25.20929, 55.4879092)
# Processing Wadi Al Safa 2...
# Found valid coordinates for Wadi Al Safa 2 using area_en: (25.098782800000002, 55.351406478118335)
# Processing Wadi Al Safa 3...
# Found valid coordinates for Wadi Al Safa 3 using area_en: (25.10571265, 55.316535293610826)
# Processing Wadi Al Safa 4...
# Found valid coordinates for Wadi Al Safa 4 using area_en: (25.0751088, 55.3175621)
# Processing Wadi Al Safa 5...
# Found valid coordinates for Wadi Al Safa 5 using area_en: (25.0842543, 55.3729759)
# Processing Wadi Al Safa 7...
# Found valid coordinates for Wadi Al Safa 7 using area_en: (25.0352976, 55.2826859)
# Processing Warsan First...
# Found valid coordinates for Warsan First using nearest_landmark_en: (25.2521287, 55.365715576690505)
# Processing Warsan Fourth...
# Could not find valid coordinates for Warsan Fourth
# Processing Zaabeel First...
# Found valid coordinates for Zaabeel First using project_name_en: (25.226715, 55.29291535225927)
# Processing Zaabeel Second...
# Found valid coordinates for Zaabeel Second using project_name_en: (25.20214795, 55.280632481978394)
# Geocoding completed and saved to geocoded_area_new.csv

# %%
geocoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   area_en    247 non-null    object
#  1   latitude   247 non-null    float64
#  2   longitude  247 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 5.9+ KB

# %%
# Assuming 'sales_data' is the original dataset with all area_en values
# Get all unique area_en values from the original dataset
all_area_en = sales_data['area_en'].unique()

# Get area_en values present in geocoded_df
geocoded_areas = geocoded_df['area_en'].unique()

# Find missing area_en
missing_areas = set(all_area_en) - set(geocoded_areas)

# Print missing area_en names
print("Areas with missing coordinates:", missing_areas)

# Optionally convert to a list if needed
missing_area_list = list(missing_areas)
# Out:
# Areas with missing coordinates: {'Al Hebiah Second', 'Al Warsan First', 'LIWAN 2', 'Al Warsan Third', 'Dubai Investment Park First', 'Al Hebiah Fourth', 'Hessyan Second', 'THE FIELD', 'Warsan Fourth', 'Al Hebiah Sixth', 'AL Athbah', 'Al Thanyah Fifth', 'AL WAHA', 'Al Aweer Second', 'Lehbab First', 'Hessyan First', 'LIWAN', 'THE VALLEY', 'Lehbab Second', "Me'Aisem Second", 'Al Hebiah Third', 'Al Aweer First', 'Madinat Hind 3', 'Al Rowaiyah Third', 'Al Hebiah Fifth', 'Muragab'}

# %%
len(missing_area_list)
# Out:
# 26

# %%
geocoded_df.head()
# Out:
#               area_en   latitude  longitude
# 0           AL BARARI  25.118865  55.320968
# 1           AL FURJAN  25.030474  55.152231
# 2    AL KHAIL HEIGHTS  25.155860  55.253688
# 3   ARABIAN RANCHES I  25.048751  55.267289
# 4  ARABIAN RANCHES II  25.034397  55.273328

# %%
# List of missing areas
missing_area_list = [
    'Al Hebiah Second', 'Al Warsan First', 'LIWAN 2', 'Al Warsan Third', 
    'Dubai Investment Park First', 'Al Hebiah Fourth', 'Hessyan Second', 
    'THE FIELD', 'Warsan Fourth', 'Al Hebiah Sixth', 'AL Athbah', 
    'Al Thanyah Fifth', 'AL WAHA', 'Al Aweer Second', 'Lehbab First', 
    'Hessyan First', 'LIWAN', 'THE VALLEY', 'Lehbab Second', 
    "Me'Aisem Second", 'Al Hebiah Third', 'Al Aweer First', 
    'Madinat Hind 3', 'Al Rowaiyah Third', 'Al Hebiah Fifth', 'Muragab'
]

# Create a DataFrame structure for manual entry
missing_coords_df = pd.DataFrame({
    'area_en': missing_area_list,
    'latitude': [None] * len(missing_area_list),  # Placeholder for latitude
    'longitude': [None] * len(missing_area_list)  # Placeholder for longitude
})

# Save the DataFrame to a CSV file for manual entry if needed
missing_coords_df.to_csv('missing_coords_manual.csv', index=False)

# Display the structure
print(missing_coords_df.head())
# Out:
#                        area_en latitude longitude
# 0             Al Hebiah Second     None      None
# 1              Al Warsan First     None      None
# 2                      LIWAN 2     None      None
# 3              Al Warsan Third     None      None
# 4  Dubai Investment Park First     None      None

# %%
manual_coords_df = pd.read_csv('missing_coords_manual.csv')
manual_coords_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   area_en    26 non-null     object
#  1   latitude   26 non-null     float64
#  2   longitude  26 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 752.0+ bytes

# %%
# Merge the datasets
combined_geocoded_df = pd.concat([geocoded_df, manual_coords_df], ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_geocoded_df.to_csv("combined_geocoded_areas.csv", index=False)

# %%
combined_geocoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   area_en    273 non-null    object
#  1   latitude   273 non-null    float64
#  2   longitude  273 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 6.5+ KB
